# %% [markdown]
# # Session 16: Word Embeddings using the Word2Vec skip-gram model
#
# ------------------------------------------------------
# *Introduction to Data Science & Machine Learning*
#
# *Pablo M. Olmos olmos@tsc.uc3m.es*
#
# ------------------------------------------------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over a data base of plain tex [Text8](http://mattmahoney.net/dc/textdata).
#
# This is a personal wrap-up of all the material provided by [Google's Deep Learning course on Udacity](https://www.udacity.com/course/deep-learning--ud730), so all credit goes to them.

# %% [markdown]
# The following [link](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) gives a very simple explanation of the model. Check also the following video.

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('xMwx2A_o5r4')

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

#Here I provide some text preprocessing functions
import preprocessing

# %%
# Lets check what version of tensorflow we have installed. The provided scripts should run with tf 1.0 and above

print(tf.__version__)
# Out:
# 1.4.0

# %% [markdown]
# We will use the plain text database from this [link](http://mattmahoney.net/dc/textdata.html)

# %%
filename = './text8.zip'

# %% [markdown]
# Read the data into a string

# %%
words = preprocessing.read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
type(words)
# Out:
# list

# %%
print(words[0:20])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english']

# %% [markdown]
# Build the dictionary and replace rare unfrequent words with UNK token.

# %%
vocabulary_size = 50000

data, count, dictionary, reverse_dictionary = preprocessing.build_dataset(vocabulary_size,words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Let's display the internal variables to better understand their structure:

# %%
print(data[:10])
print(count[:10])
# Out:
# [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]
# [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]

# %%
print(list(dictionary.items())[:10])
print(list(reverse_dictionary.items())[:10])
# Out:
# [('UNK', 0), ('the', 1), ('of', 2), ('and', 3), ('one', 4), ('in', 5), ('a', 6), ('to', 7), ('zero', 8), ('nine', 9)]
# [(0, 'UNK'), (1, 'the'), (2, 'of'), (3, 'and'), (4, 'one'), (5, 'in'), (6, 'a'), (7, 'to'), (8, 'zero'), (9, 'nine')]

# %%
print('The index of the word dictionary is %d\n' %(dictionary['crafty']))
print('The word corresponding to the index 875 is %s\n' %(reverse_dictionary[875]))
# Out:
# The index of the word dictionary is 39018
#
# The word corresponding to the index 875 is edition

# %% [markdown]
# ## Generating training batches

# %% [markdown]
# The function 'preprocessing.generate_batch' generates training batchs for the skip-gram model.
#
#
# <img src="Fig1.png" width="600" height="400">
#
# Figure borrowed from this [post](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/).

# %%
data_index = 0

"""Generate a batch of data for training.
    Args:
        batch_size: Number of samples to generate in the batch.
        
        skip_window:# How many words to consider left and right.
        
            How many words to consider around the target word, left and right.
            With skip_window=2, in the sentence above for "consider" we'll
            build the window [words, to, consider, around, the].
            
        num_skips: How many times to reuse an input to generate a label.
        
            For skip-gram, we map target word to adjacent words in the window
            around it. This parameter says how many adjacent word mappings to
            add to the batch for each target word. Naturally it can't be more
            than skip_window * 2.
            
    Returns:
        batch, labels - ndarrays with IDs.
        batch: Row vector of size batch_size containing target words.
        labels:
            Column vector of size batch_size containing a randomly selected
            adjacent word for every target word in 'batch'.
    """


print('data:', [reverse_dictionary[di] for di in data[:32]])

for num_skips, skip_window in [(2, 4)]:
    data_index = 0
    batch, labels = preprocessing.generate_batch(data, data_index, batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'UNK', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term']
#
# with num_skips = 2 and skip_window = 4:
#     batch: ['term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used', 'against', 'against', 'early', 'early', 'working', 'working']
#     labels: ['of', 'originated', 'term', 'a', 'term', 'a', 'abuse', 'working', 'abuse', 'against', 'working', 'of', 'used', 'including', 'including', 'first']

# %% [markdown]
# ## Using the above data set, now we train a skip-gram model!

# %% [markdown]
# The following [link](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) gives a very simple explanation of the model. The following figures are borrowed from that post.
#
# <img src="Fig2.png" width="600" height="400">
#
# <img src="Fig3.png" width="600" height="400">

# %%
batch_size = 32
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 32 # Random set of words to evaluate similarity on.
valid_window = 200 # Only pick samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))

num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs. YOU DON'T NEED THE ONE HOT ENCODING FOR THE INPUT!!!! 
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, train_labels, 
                                                     embed, num_sampled, vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001
data_index = 0

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):

        batch_data, batch_labels = preprocessing.generate_batch(data,data_index,batch_size, num_skips, skip_window) 
        data_index = (data_index + batch_size) % len(data)
        
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
            
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 25000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.619374
# Nearest to other: irb, los, hammond, thatched, cary, atwood, rightist, ye,
# Nearest to then: proposes, dooley, mononoke, gamble, strangle, spader, priors, tt,
# Nearest to he: autostrada, cullen, gojira, hrothgar, leif, sada, langle, hypothesized,
# Nearest to i: foucault, fiorentina, cruising, stomping, syncopation, welcoming, milford, hashshashin,
# Nearest to international: cairns, marin, plated, estranged, poking, natively, kor, ibiza,
# Nearest to or: powders, trademark, melissa, harwich, pao, maternal, guaranteed, makeover,
# Nearest to language: neglected, according, secretaries, sharif, cumming, decides, treatments, hostels,
# Nearest to is: calgary, sketches, esas, pickles, pitchfork, chirac, cingular, voltaic,
# Nearest to used: hecuba, corba, painter, lascaux, bearded, pisano, obstruct, pierluigi,
# Nearest to both: veins, felipe, mashiach, oneworld, magnesium, polling, blower, ia,
# Nearest to king: capitalisation, gorgeous, verifiable, parts, dismissal, subnational, chant, unbreakable,
# Nearest to an: satchmo, revealed, ornament, protectorates, valuables, toronto, incursions, introduction,
# Nearest to zero: wight, cauchy, seriousness, dismissal, recitation, embalmed, fatty, inclusive,
# Nearest to use: lipstick, roleplaying, fats, syed, akayev, morita, guises, summarize,
# Nearest to there: comets, duplicating, whatsoever, anemometer, jj, morisot, commendation, dramatic,
# Nearest to power: rips, marietta, zilog, dedications, academia, bullough, testimonium, mpls,
# Nearest to same: prefectural, othon, racetrack, hickok, trigonometry, hierarchy, completion, swing,
# Nearest to will: grande, payable, gerardus, spokesman, attributed, mantra, crossed, considerable,
# Nearest to many: inductors, nueva, rushed, detailed, buber, catastrophe, replicators, bedford,
# Nearest to when: teleplay, stabilizes, speeds, piracy, fantasia, centromeres, overvalued, outwardly,
# Nearest to seven: jscript, minesweeper, inextricably, flaps, teutonic, gelre, frf, tallest,
# Nearest to four: paramount, undue, renamed, adhd, abyss, nihilism, banisteriopsis, croesus,
# Nearest to through: thomson, exponentials, cylinders, aeneas, budgeted, nouns, encountering, collide,
# Nearest to their: canc, questioning, peripheries, reduced, mennonite, drummers, principle, airway,
# Nearest to she: noise, allman, youngest, distraught, bashir, uplands, beacons, aqaba,
# Nearest to s: wilford, coup, moxie, redrawing, positivism, coimbra, predominated, factual,
# Nearest to six: gilmour, hardness, arafat, luggage, homininae, id, powerpc, kanembu,
# Nearest to law: acceptability, harvests, metastability, wold, manifold, motive, poisons, weiss,
# Nearest to two: complex, moons, broker, fitzroy, proceeded, accommodations, submission, seasonal,
# Nearest to no: adiabatic, religion, synapses, kach, heresy, berry, big, cryogenics,
# Nearest to before: copied, sequentially, insert, fighters, factsheet, buried, gli, edo,
# Nearest to and: crimes, desegregation, connexion, gillies, provinces, geoffrey, hacking, eurythmics,
# Average loss at step 2000: 4.637488
# Average loss at step 4000: 4.148687
# Average loss at step 6000: 4.023308
# Average loss at step 8000: 3.789332
# Average loss at step 10000: 3.797897
# Average loss at step 12000: 3.878916
# Average loss at step 14000: 3.782239
# Average loss at step 16000: 3.748933
# Average loss at step 18000: 3.599297
# Average loss at step 20000: 3.713158
# Average loss at step 22000: 3.765039
# Average loss at step 24000: 3.587925
# Nearest to other: strive, some, riddler, both, include, these, contended, carpets,
# Nearest to then: never, eastenders, also, when, lovable, koyaanisqatsi, mononoke, benefited,
# Nearest to he: it, she, they, never, palliative, blond, casting, this,
# Nearest to i: t, you, would, bibliographic, petrovich, we, they, eight,
# Nearest to international: tudes, ludicrous, sunflower, scully, kondratiev, plated, henotheism, melanie,
# Nearest to or: and, terrence, clergymen, egmont, a, nun, pune, to,
# Nearest to language: earls, polarity, depot, synopsis, rye, ibo, writers, country,
# Nearest to is: was, are, has, monomorphism, can, tartan, colbert, ec,
# Nearest to used: considered, known, found, shown, seen, described, corsica, available,
# Nearest to both: these, many, wieman, battering, which, christian, veins, other,
# Nearest to king: leaking, hao, buyers, deleterious, bambara, vow, chant, chlamydia,
# Nearest to an: another, pipe, succeeded, irreconcilable, messengers, hilarious, coachella, envelope,
# Nearest to zero: five, nine, four, eight, three, six, seven, two,
# Nearest to use: meteoric, ova, because, tana, belief, syed, afro, swapping,
# Nearest to there: it, they, often, which, not, now, tibeto, what,
# Nearest to power: alphorn, majuro, extinction, die, jail, unfiltered, meditation, molly,
# Nearest to same: satem, second, blemish, last, of, trigonometry, imac, first,
# Nearest to will: would, may, to, can, intervention, could, pollutants, should,
# Nearest to many: some, these, both, several, reject, various, computers, publicize,
# Nearest to when: if, although, after, before, through, where, against, was,
# Nearest to seven: eight, six, five, nine, four, three, zero, one,
# Nearest to four: five, eight, nine, seven, three, zero, six, two,
# Nearest to through: when, unknowingly, soundly, with, of, midfielders, zone, within,
# Nearest to their: its, the, her, some, any, fantastical, his, kinks,
# Nearest to she: he, ornithology, it, they, who, only, reina, yeomen,
# Nearest to s: and, her, afforded, gluons, usn, unam, lodged, aaa,
# Nearest to six: eight, seven, five, three, nine, four, zero, two,
# Nearest to law: exacted, nieve, paulette, equality, misdiagnosed, electrodynamics, wold, admiral,
# Nearest to two: three, one, four, five, six, zero, eight, nine,
# Nearest to no: asymptotic, a, it, discretion, ncaa, often, still, this,
# Nearest to before: after, when, since, accompaniment, scholz, during, until, bolan,
# Nearest to and: of, for, or, s, underlying, to, in, a,
# Average loss at step 26000: 3.663524
# Average loss at step 28000: 3.655734
# Average loss at step 30000: 3.486271
# Average loss at step 32000: 3.522590
# Average loss at step 34000: 3.382424
# Average loss at step 36000: 3.497429
# Average loss at step 38000: 3.578393
# Average loss at step 40000: 3.665508
# Average loss at step 42000: 3.512351
# Average loss at step 44000: 3.550210
# Average loss at step 46000: 3.519938
# Average loss at step 48000: 3.541693
# Average loss at step 50000: 3.580842
# Nearest to other: various, richey, cimeti, carats, colspan, oppositional, licks, oeis,
# Nearest to then: newman, tim, abundant, defendant, he, never, handguard, disagreeable,
# Nearest to he: she, it, they, there, however, never, later, then,
# Nearest to i: ii, we, iii, you, she, georg, pronounce, they,
# Nearest to international: regulator, mclean, disastrously, torque, conte, ub, spark, piccadilly,
# Nearest to or: and, cashmere, the, specialising, tdma, serge, meaningful, cuailnge,
# Nearest to language: languages, archive, spoken, sophist, ibo, shores, loanwords, rockwell,
# Nearest to is: was, became, are, makes, though, were, does, has,
# Nearest to used: known, regarded, found, described, shown, considered, referred, seen,
# Nearest to both: these, chromatic, curonian, material, californian, flavian, stoker, fsb,
# Nearest to king: prince, hellman, duke, mandate, missouri, dahl, nagy, emperor,
# Nearest to an: tiberius, no, the, irreconcilable, reverberation, isomorphic, inevitably, classified,
# Nearest to zero: five, nine, four, six, eight, two, seven, three,
# Nearest to use: cause, most, litigation, gelfand, lexemes, blatant, amg, practice,
# Nearest to there: they, he, now, still, we, often, it, she,
# Nearest to power: legislator, ground, jail, justified, cosmos, proudhon, buoyed, minurso,
# Nearest to same: following, second, term, empirical, darkest, carotenoids, across, from,
# Nearest to will: would, could, can, should, may, must, might, had,
# Nearest to many: some, these, several, those, such, were, hatchet, languages,
# Nearest to when: where, after, before, did, incubus, rory, seizing, strasberg,
# Nearest to seven: nine, eight, six, five, four, three, zero, one,
# Nearest to four: zero, eight, six, seven, nine, three, five, two,
# Nearest to through: from, until, original, basically, within, while, under, in,
# Nearest to their: his, its, her, the, any, our, them, your,
# Nearest to she: he, they, it, there, we, you, never, worse,
# Nearest to s: thurber, bell, tijuana, vaughan, jaw, whose, murmansk, blum,
# Nearest to six: eight, nine, seven, five, zero, four, three, one,
# Nearest to law: mathematicians, admiral, equality, availability, briggs, bawdy, rood, empire,
# Nearest to two: three, one, zero, five, nine, four, eight, seven,
# Nearest to no: asymptotic, still, an, substituted, transmits, hermitian, enough, hansa,
# Nearest to before: after, when, ecma, later, had, during, but, universality,
# Nearest to and: or, but, of, in, with, from, np, jogaila,
# Average loss at step 52000: 3.495413
# Average loss at step 54000: 3.536460
# Average loss at step 56000: 3.584747
# Average loss at step 58000: 3.486636
# Average loss at step 60000: 3.508045
# Average loss at step 62000: 3.592625
# Average loss at step 64000: 3.525245
# Average loss at step 66000: 3.560082
# Average loss at step 68000: 3.491695
# Average loss at step 70000: 3.572708
# Average loss at step 72000: 3.517973
# Average loss at step 74000: 3.569699
# Nearest to other: many, various, most, reconquer, item, human, rather, tautologies,
# Nearest to then: stopped, never, ever, sparked, gauge, tashfin, if, facing,
# Nearest to he: she, it, they, never, i, there, dylan, who,
# Nearest to i: we, he, you, t, ii, rc, iii, larwood,
# Nearest to international: economic, arbitration, website, unwarranted, rtf, amplifier, sinhalese, american,
# Nearest to or: and, frontiersman, frankenheimer, ambedkar, pleasuredome, automakers, pegged, criticised,
# Nearest to language: religion, word, raum, term, brazilian, ibo, shikoku, appellations,
# Nearest to is: was, has, became, does, are, though, were, while,
# Nearest to used: seen, regarded, available, known, possible, referred, described, considered,
# Nearest to both: pyrite, unscrupulous, the, melodrama, catwoman, ves, dashes, telecommunications,
# Nearest to king: duke, prince, emperor, dahl, father, anthropologist, son, god,
# Nearest to an: faqs, deterrence, hiss, reverberation, heterotic, aids, retribution, calista,
# Nearest to zero: five, four, seven, six, nine, eight, two, three,
# Nearest to use: need, support, encode, transistors, chisinau, names, form, computers,
# Nearest to there: they, it, she, still, he, tibeto, usually, also,
# Nearest to power: energy, cyprus, alleles, protection, cosmos, orphaned, compensates, minamoto,
# Nearest to same: first, next, keane, following, across, entire, real, term,
# Nearest to will: can, could, may, would, must, should, might, cannot,
# Nearest to many: those, some, several, various, these, other, few, most,
# Nearest to when: if, before, although, where, marathi, until, confuse, as,
# Nearest to seven: nine, six, eight, four, five, zero, three, one,
# Nearest to four: six, three, five, nine, seven, eight, two, zero,
# Nearest to through: from, within, in, off, browsers, ei, onto, to,
# Nearest to their: his, its, her, your, our, the, zealot, whose,
# Nearest to she: he, it, never, there, they, originally, once, cushion,
# Nearest to s: whose, abigail, where, com, the, rial, and, directness,
# Nearest to six: eight, seven, four, five, nine, three, zero, two,
# Nearest to law: criminally, movement, johannesburg, happenings, mathematicians, rood, background, gurmukhi,
# Nearest to two: three, four, five, six, one, zero, seven, eight,
# Nearest to no: any, hippolytus, onward, diss, heenan, alderney, negotiating, rote,
# Nearest to before: after, when, at, down, though, during, on, preferentially,
# Nearest to and: in, of, or, resumes, sod, but, vs, include,
# Average loss at step 76000: 3.373231
# Average loss at step 78000: 3.198165
# Average loss at step 80000: 3.530721
# Average loss at step 82000: 3.493162
# Average loss at step 84000: 3.417854
# Average loss at step 86000: 3.521660
# Average loss at step 88000: 3.443026
# Average loss at step 90000: 3.526745
# Average loss at step 92000: 3.489720
# Average loss at step 94000: 3.479717
# Average loss at step 96000: 3.515148
# Average loss at step 98000: 3.395745
# Average loss at step 100000: 3.401685
# Nearest to other: different, various, tautologies, encarta, licks, variations, many, canetti,
# Nearest to then: never, thus, and, simply, he, also, granular, here,
# Nearest to he: she, it, they, who, actually, there, never, dylan,
# Nearest to i: you, we, ii, god, he, t, charlatans, malawian,
# Nearest to international: economic, american, liberator, australian, governess, official, italian, tourism,
# Nearest to or: and, than, favoring, vendetta, while, though, offutt, lothian,
# Nearest to language: word, bangla, languages, ibo, spoken, bouvet, railtrack, indexes,
# Nearest to is: was, has, are, by, were, seems, makes, being,
# Nearest to used: written, seen, known, referred, found, applied, recognized, available,
# Nearest to both: some, gestapo, several, their, msp, loving, these, many,
# Nearest to king: husband, mastering, mactutor, krzysztof, spirit, pont, city, unmop,
# Nearest to an: kwazulu, disaccharide, crossfire, margherita, hiss, tiberius, retribution, this,
# Nearest to zero: five, eight, seven, nine, six, three, four, two,
# Nearest to use: need, course, objected, end, catalog, beginning, addition, form,
# Nearest to there: they, now, we, still, he, it, generally, disastrous,
# Nearest to power: energy, gas, jiao, cyprus, range, odorless, complex, force,
# Nearest to same: following, first, entire, opening, last, real, final, phylogenetic,
# Nearest to will: can, must, would, might, could, should, may, cannot,
# Nearest to many: some, several, those, numerous, these, various, their, the,
# Nearest to when: until, before, while, though, if, rhead, however, as,
# Nearest to seven: six, eight, three, nine, four, one, five, zero,
# Nearest to four: three, six, five, seven, one, eight, two, nine,
# Nearest to through: from, into, until, across, on, off, for, in,
# Nearest to their: his, its, the, these, your, her, our, pic,
# Nearest to she: he, it, they, stated, actually, who, you, i,
# Nearest to s: of, whose, the, his, including, and, at, your,
# Nearest to six: eight, seven, three, five, four, nine, one, zero,
# Nearest to law: supporters, policy, mathematicians, nebula, ogden, retrial, ghz, criminally,
# Nearest to two: three, five, one, four, eight, six, seven, nine,
# Nearest to no: rote, your, orientations, about, enough, little, hippolytus, haeckel,
# Nearest to before: after, though, when, during, where, until, behind, while,
# Nearest to and: but, or, who, to, however, including, in, then,

# %% [markdown]
# This is what an embedding looks like:

# %%
print(final_embeddings[2,:])
# Out:
# [ 0.07486219  0.13746096 -0.01321128  0.02182575 -0.01704228 -0.11280496
#  -0.09018616 -0.01380115  0.00629439  0.03425485  0.12132603 -0.20750435
#   0.02571142 -0.05017726 -0.02067713  0.05777926  0.04365191  0.0336484
#   0.02030769 -0.04478797  0.2781505   0.01671201 -0.01049547  0.1649261
#  -0.11132132  0.02352094  0.11872099  0.01570104 -0.04495034  0.04207507
#   0.09078976  0.06249509 -0.09208255  0.08988151 -0.12040462  0.07177086
#  -0.0385922   0.04010707  0.01648428 -0.05343294  0.03283805  0.14198095
#   0.02297745 -0.07839058  0.12095632 -0.01605355 -0.24982557 -0.02591949
#  -0.13883644 -0.0054848  -0.05182092 -0.02280014 -0.03568238  0.02353876
#  -0.03572326  0.12693103  0.21457452  0.11682206  0.08601998 -0.00379734
#   0.01745305 -0.17526007 -0.04429409 -0.00644602  0.04488723  0.12378585
#   0.06766355 -0.02242688  0.0623868  -0.10965419 -0.0372259  -0.07083723
#  -0.07962716 -0.12927721 -0.00873222 -0.02333568 -0.07338103  0.01147336
#   0.08805826 -0.05157203 -0.10044507  0.08862761 -0.01172975  0.2174631
#  -0.02988652  0.08127817  0.03062417 -0.14791732 -0.05210344 -0.07456053
#  -0.06754375  0.08220741 -0.00607643 -0.07442044 -0.03741262 -0.15366611
#  -0.07096912 -0.15811926 -0.06421299 -0.17940812 -0.1362248  -0.04275834
#   0.07202149 -0.03803123  0.04934408 -0.06973111  0.08477265  0.01721234
#   0.01568906  0.05493201  0.02308586 -0.07017574 -0.02915493  0.04720661
#  -0.08733504  0.01899477 -0.13552341  0.15414286  0.00567007 -0.00293933
#  -0.03522214 -0.08708336 -0.05230391  0.05773596  0.02399196 -0.0355201
#   0.11562935 -0.11553583]

# %% [markdown]
# The embeddings have unit norm!

# %%
print(np.sum(np.square(final_embeddings[40000,:])))
# Out:
# 1.0

# %% [markdown]
# Now we project the emmbeding vectors into a 2-dimensional space using [TSNE](https://lvdmaaten.github.io/publications/papers/JMLR_2008.pdf)
#
# We use the [TSNE sklearn implementation](https://lvdmaaten.github.io/publications/papers/JMLR_2008.pdf)

# %%
num_points = 200

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=500)

two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %% [markdown]
# Lets visualize the result

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
